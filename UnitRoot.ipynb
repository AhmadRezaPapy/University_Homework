# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
# !pip install tabulate
from tabulate import tabulate
from statsmodels.tsa.stattools import adfuller
file_path = "/content/sample_data/Data.xlsx"
df = pd.read_excel(file_path)
df
# Out:
# ...
#     Year       rent        INF        ICT      GROW     ARZ       ROL  \
# 0   1379  30.663775  14.476751   0.934190  5.845527    8131 -0.519493
# 1   1380  21.488217  11.274247   1.484221  2.392173    7925 -0.600000
# 2   1381  20.443741  14.335934   4.626175  8.078829    7991 -0.821778
# 3   1382  22.044917  16.468012   6.933722  8.639298    8323 -0.680516
# 4   1383  25.199002  14.761509   7.490000  4.336666    8747 -0.673581
# 5   1384  31.607676  13.433118   8.100000  3.189804    9042 -0.865804
# 6   1385  31.558204  10.015898   8.760000  4.999795    9226 -0.994356
# 7   1386  26.125240  17.341040   9.470000  8.155774    9357 -1.027452
# 8   1387  30.565974  25.410509  12.020000  0.250857    9667 -0.978464
# 9   1388  17.551259  13.551555  13.800000  1.007385    9979 -1.053678
# 10  1389  20.224836  10.089363  15.900000  5.797938   10601 -1.026664
# 11  1390  22.351459  26.293386  19.000000  2.645718   13568 -0.967787
# ...

# %%
X = df['INF'].values
length_X = X.shape[0]
if length_X > 100:
    autolag = 'AIC'
else:
    autolag = 'BIC'

result = adfuller(X, regression='ct')

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('lags: %f' % result[2])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print("در مرحله اول(روند و عرض از مبدا)مانا است")
else:
    print("در مرحله اول(روند و عرض از مبدا)مانا نیست")
################################################################
result = adfuller(X, regression='c')

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('lags: %f' % result[2])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print("در مرحله دوم(فقط عرض از مبدا)مانا است")
else:
    print("در مرحله دوم(فقط عرض از مبدا)مانا نیست")
##################################################################
result = adfuller(X, autolag='AIC', regression='n')

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('lags: %f' % result[2])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print("در مرحله سوم(نه عرض از مبدا نه روند)مانا است")
else:
    print("در مرحله سوم(نه عرض از مبدا نه روند)مانا نیست")
 #####################################################################
    df['DIFF'] = df['INF'].diff()
    Y = df['DIFF'].dropna().values

    result = adfuller(Y, regression='ct')

    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('lags: %f' % result[2])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

    if result[0] < result[4]["5%"]:
        print("در مرحله چهارم (تفاضل گیری مرتبه اول و هم عرض از مبدا و روند)مانا است")
    else:
        print("در مرحله چهارم (تفاضل گیری مرتبه اول و هم عرض از مبدا و روند)مانا نیست")
########################################################################################################
        result = adfuller(Y, regression='c')

        print('ADF Statistic: %f' % result[0])
        print('p-value: %f' % result[1])
        print('lags: %f' % result[2])
        print('Critical Values:')
        for key, value in result[4].items():
            print('\t%s: %.3f' % (key, value))

        if result[0] < result[4]["5%"]:
            print("در مرحله چهارم (تفاضل گیری مرتبه اول و فقط عرض از مبدا)مانا است")
        else:
            print("در مرحله چهارم (تفاضل گیری مرتبه اول و فقط عرض از مبدا)مانا نیست")
#########################################################################################################
            result = adfuller(Y, regression='n')

            print('ADF Statistic: %f' % result[0])
            print('p-value: %f' % result[1])
            print('lags: %f' % result[2])
            print('Critical Values:')
            for key, value in result[4].items():
                print('\t%s: %.3f' % (key, value))

            if result[0] < result[4]["5%"]:
                print("در مرحله چهارم (تفاضل گیری مرتبه اول و فقط عرض از مبدا)مانا است")
            else:
                print("در مرحله چهارم (تفاضل گیری مرتبه اول و فقط عرض از مبدا)مانا نیست")
##################################################################################################################
                df['DIFF2'] = df['DIFF'].diff()
                Y = df['DIFF2'].dropna().values

                result = adfuller(Y)

                print('ADF Statistic: %f' % result[0])
                print('p-value: %f' % result[1])
                print('lags: %f' % result[2])
                print('Critical Values:')
                for key, value in result[4].items():
                    print('\t%s: %.3f' % (key, value))
                if result[0] < result[4]["5%"]:
                    print("در مرحله پنجم (تفاضل گیری مرتبه دوم)مانا است")
                else:
                    print("در مرحله پنجم (تفاضل گیری مرتبه دوم)مانا نیست")
######################################################################################################
# Out:
# ADF Statistic: -2.140339
# p-value: 0.523447
# lags: 8.000000
# Critical Values:
# 	1%: -4.884
# 	5%: -3.822
# 	10%: -3.359
# در مرحله اول(روند و عرض از مبدا)مانا نیست
# ADF Statistic: -2.288093
# p-value: 0.175837
# lags: 2.000000
# Critical Values:
# 	1%: -3.833
# 	5%: -3.031
# 	10%: -2.656
# در مرحله دوم(فقط عرض از مبدا)مانا نیست
# ADF Statistic: -0.143622
# p-value: 0.634498
# lags: 0.000000
# Critical Values:
# 	1%: -2.680
# 	5%: -1.958
# 	10%: -1.608
# در مرحله سوم(نه عرض از مبدا نه روند)مانا نیست
# ADF Statistic: -4.735180
# p-value: 0.000607
# lags: 0.000000
# Critical Values:
# 	1%: -4.499
# 	5%: -3.658
# 	10%: -3.269
# در مرحله چهارم (تفاضل گیری مرتبه اول و هم عرض از مبدا و روند)مانا است
